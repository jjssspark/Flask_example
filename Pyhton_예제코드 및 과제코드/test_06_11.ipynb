# %% [markdown]
# 파이썬 기본문법

# %% [markdown]
# 자료형 (문자열)

# %%
num1 = 10
num2 = -20
print(num1, num2)
# Out:
# 10 -20

# %%
num1 = 3.14
num2 = -2.718
print(num1, num2)
# Out:
# 3.14 -2.718

# %%
str1 = 'Hello'
str2 = "Python"
print(str1, str2)
# Out:
# Hello Python

# %%
#멀티라인 문자열
str3 = '''This is 
a multi-line 
string'''
print(str3)
# Out:
# This is a multi-line string
